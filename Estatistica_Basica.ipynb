# %% [markdown]
# <a href="https://colab.research.google.com/github/n0va1s/ciencia_dados_geograficos/blob/main/Estatistica_Basica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def imc(peso, altura):
  if peso <= 0:
    print("Por favor verifique o peso informado")
  if altura <= 0.2:
    print("Por favor verifique a altura informada")

  if peso <= 0 or altura <= 0.2:
    return None, "Dados inválidos"

  indice = round(peso / (altura ** 2 ), 2)

  if indice <= 18.5:
    classificacao = "Abaixo do peso"
  elif indice <= 24.99:
    classificacao = "Peso normal"
  elif indice <= 29.99:
    classificacao = "Sobrepeso"
  else:
    classificacao = "Obesidade"

  return indice, classificacao

# %%
indice, classificacao = imc(94,1.74)
print(indice, classificacao)
# Out:
# 31.05 Obesidade

# %%
# !pip install numpy
# !pip install pandas
# !pip install scipy

# %%
import pandas as pd
import numpy as np
import statistics as st
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency, spearmanr
from scipy.stats import skewnorm, skew, kurtosis, t, chi2_contingency, spearmanr
from matplotlib.ticker import PercentFormatter

# %%
iris =  sns.load_dataset("iris")
# topo
iris.head()
# fundo
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# contagem (campo sem caracteres)
# iris.species.value_counts()
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
